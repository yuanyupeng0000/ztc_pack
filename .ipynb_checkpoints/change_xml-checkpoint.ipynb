# %%
import os
import time
import xml.dom.minidom as xmldom

SEED_XML_DIR = '/data/wxjs/Annotations/'
SEED_IMG_DIR = '/data/wxjs/JPEGImages/'
SEED_CHG_DIR = '/data/wxjs/Changed_Annotations/'

start_time = time.time()

seed_xml_names = os.listdir(SEED_XML_DIR)
seed_img_names = os.listdir(SEED_IMG_DIR)
seed_chg_names = os.listdir(SEED_CHG_DIR)
i = 0
for xml in seed_xml_names:
    print(xml)
    dom = xmldom.parse(SEED_XML_DIR + xml)
    root = dom.documentElement #
    obj_elements = root.getElementsByTagName('object')
    if(len(obj_elements) > 0):
        for obj_element in obj_elements:
            name = obj_element.getElementsByTagName('name')
            if(len(name) > 0):
                name_data = name.item(0).firstChild.data
                #print('name_data: ' + name_data)
            cover = obj_element.getElementsByTagName('cover')
            if(len(cover) > 0):
                cover_data = cover.item(0).firstChild.data
                #print('cover_data: ' + cover_data)
            spray = obj_element.getElementsByTagName('spray')
            if(len(spray) > 0):
                spray_data = spray.item(0).firstChild.data
                #print('spray_data: ' + spray_data)
            name.item(0).firstChild.data = name_data[:7] + "_" + str(cover_data) + str(spray_data)
    try:
        with open(SEED_CHG_DIR + xml,'w',encoding='UTF-8') as fh:           
            # 4.writexml()第一个参数是目标文件对象，第二个参数是根节点的缩进格式，第三个参数是其他子节点的缩进格式，
            # 第四个参数制定了换行格式，第五个参数制定了xml内容的编码。
            dom.writexml(fh,indent='',addindent='\t',newl='\n',encoding='UTF-8')
            print('写入xml OK!')
            i = i+1
    except Exception as err:
        print('错误信息：{0}'.format(err))
# Out:
# 01c08702b7f7f562547e2a8718c8ab07.xml
# 写入xml OK!
# 022014a454e80e353bef2690ea813d87.xml
# 写入xml OK!
# 014f328da8e0a69c217fc10635c3f7a8.xml
# 写入xml OK!
# 0127d83c870c04c6db0682ed6dd27162.xml
# 写入xml OK!
# 01dce76be1b050dcf3f1014cd670acfc.xml
# 写入xml OK!
# 005616f3d4f6cbdb9f41f708f193cb38.xml
# 写入xml OK!
# 02eade01fd2a457c1cb767788334a13e.xml
# 写入xml OK!
# 0232edb69067a70f65bdfb1640502e93.xml
# 写入xml OK!
# 017b7fbbb261669feae86d3187d774ae.xml
# 写入xml OK!
# 0273f116e6f887b524893d339d296ad3.xml
# 写入xml OK!
# 02417750d2945c439841ba60ebcf7ad9.xml
# 写入xml OK!
# 01ce8475f9a2a431556d3fb5bee43aae.xml
# 写入xml OK!
# 009966ce9c9b2fc621a0ccf501d870c3.xml
# 写入xml OK!
# 005cbecea885d1418150bbdedca6e9bc.xml
# 写入xml OK!
# 0147802145417a88086f3977a55dfd6d.xml
# 写入xml OK!
# 020df1c1a3fe14ec73e1e4a6a31cea93.xml
# 写入xml OK!
# 002733143d3fcbf90b24d51b04fb1168.xml
# 写入xml OK!
# 0077e09396aa0ba75fcaae1e3799d3d0.xml
# 写入xml OK!
# 0288adf5b73827b8669d7462ef6d8de5.xml
# 写入xml OK!
# 026c62da4c7183cfd0b2dad62cb2ecde.xml
# 写入xml OK!
# 01802c0bf7d1e87bcbb2f886578b9c39.xml
# 写入xml OK!
# 02dcac9b76c1fc3ad543d32340ab26d7.xml
# 写入xml OK!
# 00d4510ffd887a5551ca46b290970720.xml
# 写入xml OK!
# 01c093263e35cd0f9dc61963fa24c147.xml
# 写入xml OK!
# 00b75476e165a156a73c29266dfdcb9e.xml
# 写入xml OK!
# 024ba4df15d6edf6005f0d68ecbf0b99.xml
# 写入xml OK!
# 00b3d7c4884e52899ddce21fa5d4eea7.xml
# 写入xml OK!
# 0232a676ea70ec4533d2d397129da511.xml
# 写入xml OK!
# 024e2a12a1e16f32256427efa4a299bd.xml
# 写入xml OK!
# 00013ba74afbf27e0e41fd488be62c40.xml
# 写入xml OK!
# 01e6f58fb69fcbf3c355256c619e0e43.xml
# 写入xml OK!
# 00242cb61a9fb9194e014b3bcc448600.xml
# 写入xml OK!
# 0263de554ae90cb5dcddd4eab31f5172.xml
# 写入xml OK!
# 01d84d68f98ba89a3ac6bcb676f7b00c.xml
# 写入xml OK!
# 01d9ad47ab619f0b0664e986ea790c06.xml
# 写入xml OK!
# 023a381f2a1cf5ee8c11c1c9f0eadd2f.xml
# 写入xml OK!
# 0008ec851e66864a9ad38161f7e9d5a8.xml
# 写入xml OK!
# 0102e8b3e006c5b0146ec15cb4ea95a0.xml
# 写入xml OK!
# 021c507164d4d5e37cbae8cbac3199fd.xml
# 写入xml OK!
# 0190b4cb574472b6f9f5c0628f4cdd5c.xml
# 写入xml OK!
# 02acfbe1bcbb24461b3550c8bcb2d9d7.xml
# 写入xml OK!
# 00046e49559722ee8e8159593d028888.xml
# 写入xml OK!
# 00c757ba7df238c09f08a3408664bded.xml
# 写入xml OK!
# 00ea97e2c06a75da09830c3555d02c90.xml
# 写入xml OK!
# 0153c2a1a24e2ba048f20b363b17d28f.xml
# 写入xml OK!
# 0047a5d7a9d35a7d1a94dd4664f99ae1.xml
# 写入xml OK!
# 018ea2c4b93665fef3b32a5eef45435a.xml
# 写入xml OK!
# 00b63c888cf7ff163db205a913bd6ee9.xml
# 写入xml OK!
# 01b99b385ba6ec46a0eaac59ff36e572.xml
# 写入xml OK!
# 02ede9e5b79d2c34f3ac0d7d33267922.xml
# 写入xml OK!
# 00c3c4021faa442717308145805b2154.xml
# 写入xml OK!
# 010a2f7c617fdeddb09bec335df98e15.xml
# 写入xml OK!
# 02ac13bf8f01cb1533f3a9ee1b4bbf19.xml
# 写入xml OK!
# 0267f10e5ec70fdd403e115d0311dfed.xml
# 写入xml OK!
# 01767776d90155853574bbf9b8f66484.xml
# 写入xml OK!
# 00efb26a10e85a47f3fd6bb8852896b0.xml
# 写入xml OK!
# 018eb3759c29cdd57e523a869ff66cf6.xml
# 写入xml OK!
# 01a60583a84af4b413a32fe0df7b9de7.xml
# 写入xml OK!
# 00feca2fa9a903eac2dbc485cb55514f.xml
# 写入xml OK!
# 01c3ad5ee6a8a6fe0503383cf8eb7980.xml
# 写入xml OK!
# 00944c7a90932edf65e1c47f09270132.xml
# 写入xml OK!
# 00acecb11ebad9b1c3647977e15b472b.xml
# 写入xml OK!
# 0025e474100b4f05756e0df68619a0f0.xml
# 写入xml OK!
# 00c47513ebb05513941987d5387d36ce.xml
# 写入xml OK!
# 006269facabc38b7ecd5243e286c67ae.xml
# 写入xml OK!
# 009b89facf5c1163a495ea3f141ed2d2.xml
# 写入xml OK!
# 005e8deb6c86fbcbe678023a6b5270a8.xml
# 写入xml OK!
# 005365811a8f2de4d061fb2f824ff248.xml
# 写入xml OK!
# 010237b9a95b6133bba49b4884ce2e42.xml
# 写入xml OK!
# 02af7fa274a3a49e9f9f3a8255eb6203.xml
# 写入xml OK!
# 013643127506a43a01e303a725a8126f.xml
# 写入xml OK!
# 01510218356609bbbbf72508a796fea5.xml
# 写入xml OK!
# 02013bb767e4c5b2fdbd0171552be57f.xml
# 写入xml OK!
# 0221579b3252d9bebb81798cf8543809.xml
# 写入xml OK!
# 022d0841346351c4c8f767242d6d5456.xml
# 写入xml OK!
# 01017b4f5dc5d635199d9670afd949fe.xml
# 写入xml OK!
# 01c672bdb18dc60de44be911d0f5a6a2.xml
# 写入xml OK!
# 025017ce46d063cb1f5db57fe2e48990.xml
# 写入xml OK!
# 0230f60cfb5c626ea94eb4f3b0541e9c.xml
# 写入xml OK!
# 00f1e9b50e4a95794f8c406f29570ec5.xml
# 写入xml OK!
# 0252566ab79f486f5e29b64e6fdd18b8.xml
# 写入xml OK!
# 02b98db06cc272ca4038191c13753f04.xml
# 写入xml OK!
# 0012cad44cf86093e6393e59e0d6efeb.xml
# 写入xml OK!
# 008ee7bc868a0876eece3a7d5b589f56.xml
# 写入xml OK!
# 028b5c810371992d4ab9505dbda4ad6b.xml
# 写入xml OK!
# 022fbf74bf12693e72420f90672b47f2.xml
# 写入xml OK!
# 027b9548055ecff57555f8ed1c6b15c3.xml
# 写入xml OK!
# 0180b31147d36ae5a32edd9a3a3940e3.xml
# 写入xml OK!
# 02031672a0534179f387ef3d11417a4e.xml
# 写入xml OK!
# 00802a2d26b7580634540c282806f6a1.xml
# 写入xml OK!
# 0294c72c3651576bf1d6665bfed70576.xml
# 写入xml OK!
# 02126f73a472cafe87c38f74e420d75d.xml
# 写入xml OK!
# 01b28ccf26649a4d68b7796841c2c2a4.xml
# 写入xml OK!
# 00d5e6d41cb26afdfdca62ec3d0e88df.xml
# 写入xml OK!
# 00a9e6f925d59563f493b282ed110cbc.xml
# 写入xml OK!
# 01b3abc94ea858bc2042b9d072279346.xml
# 写入xml OK!
# 01f62baa787a82bf7585faf3ce82a8f4.xml
# 写入xml OK!
# 01bf45b5d36556ffc180c402857dc05a.xml
# 写入xml OK!
# 02878b1672b709ecf0ff28b9f6a51001.xml
# 写入xml OK!
# 02e5e7e4dc66982c8e5a5498d3e1742d.xml
# 写入xml OK!
